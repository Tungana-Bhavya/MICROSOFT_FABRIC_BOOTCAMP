# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

df = spark.sql("SELECT * FROM Laketbhavya0541.dimension_city LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, ede268c2-3946-4ac9-9509-9037db6fee6e)

# %%
# Load multiple sheets ('Sales', 'Customer', 'Geography', 'Item') from an Excel file into separate Pandas DataFrames

import pandas as pd
excel_file_path = "https://github.com/amitchandakpbi/powerbi/raw/refs/heads/main/Sales%20Data%20for%20Fabric.xlsx"
# use pandas to read file
df_sales = pd.read_excel(excel_file_path, sheet_name = "Sales")
df_customer = pd.read_excel(excel_file_path, sheet_name = "Customer")
df_geo = pd.read_excel(excel_file_path, sheet_name = "Geography")
df_item = pd.read_excel(excel_file_path, sheet_name = "Item")
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 4, Finished, Available, Finished)

# %%
print(df_sales.head())
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 5, Finished, Available, Finished)
#    OrderNo  ItemID  SalesDate DeilveryDate  CustomerId  CityId  Qty  Price  \
# 0    20277      37 2020-10-03   2020-10-06        2691      26    1    233
# 1    22328      23 2020-10-03   2020-10-07        6085      61    1     60
# 2    22784      53 2020-10-03   2020-10-09        3562      19    1    333
# 3    25881      14 2020-10-03   2020-10-09         338      52    2    753
# 4    26399      52 2020-10-03   2020-10-13        4995      51    2     53
#
#    cost  DiscountPercent
# 0   172               12
# 1    54                9
# 2   259                5
# 3   301               39
# 4    45               28

# %%
display(df_sales)
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 1b33330f-3007-4f5c-b952-463d78705489)

# %%
# Convert Pandas DataFrame to Spark DataFrame

sales = spark.createDataFrame(df_sales)
customer = spark.createDataFrame(df_customer)
geography = spark.createDataFrame(df_geo)
item = spark.createDataFrame(df_item)
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 7, Finished, Available, Finished)

# %%
# Show stats for numeric columns in 'item', 'sales', 'customer' and 'geography'

sales.describe().show()
customer.describe().show()
geography.describe().show()
item.describe().show()
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 8, Finished, Available, Finished)
# +-------+-----------------+-----------------+------------------+------------------+------------------+------------------+------------------+----------------+
# |summary|          OrderNo|           ItemID|        CustomerId|            CityId|               Qty|             Price|              cost| DiscountPercent|
# +-------+-----------------+-----------------+------------------+------------------+------------------+------------------+------------------+----------------+
# |  count|            30000|            30000|             30000|             30000|             30000|             30000|             30000|           30000|
# |   mean|          15000.5|          23.8998| 2586.925166666667|           47.0278|1.6637666666666666|207.29673333333332|138.50326666666666|         23.0316|
# | stddev|8660.398374208868|12.96739623332954|1601.8359893940074|28.381839465646266|0.6669297604688745| 322.9430701484105|199.58852666255197|12.9955157992169|
# |    min|                1|                1|                 1|                 1|                 1|                40|                36|               1|
# |    max|            30000|               55|              6501|               100|                 3|              1733|              1299|              45|
# +-------+-----------------+-----------------+------------------+------------------+------------------+------------------+------------------+----------------+
#
# +-------+------------------+-----------------+---------------+---------+------------+
# |summary|        CustomerId|              Age|           City|    State|        Name|
# +-------+------------------+-----------------+---------------+---------+------------+
# |  count|              6138|             6138|           6138|     6138|        6138|
# |   mean|  3116.08211143695|34.43189964157706|           NULL|     NULL|        NULL|
# | stddev|1831.4120792734825|8.169102797527293|           NULL|     NULL|        NULL|
# |    min|                 1|               20|    Albuquerque|   Alaska|  Customer 1|
# |    max|              6501|               70|Winstonâ€“Salem|Wisconsin|Customer 999|
# +-------+------------------+-----------------+---------------+---------+------------+
#
# +-------+------------------+---------------+---------+
# |summary|            CityId|           City|    State|
# +-------+------------------+---------------+---------+
# |  count|               100|            100|      100|
# |   mean|              50.5|           NULL|     NULL|
# | stddev|29.011491975882016|           NULL|     NULL|
# |    min|                 1|    Albuquerque|   Alaska|
# |    max|               100|Winstonâ€“Salem|Wisconsin|
# +-------+------------------+---------------+---------+
#
# +-------+------------------+------+------------------+------------------+------------------+-------+----------+-----------+
# |summary|            ItemId|  Name|           BrandId|        CategoryId|     SubCategoryId|  Brand|  Category|SubCategory|
# +-------+------------------+------+------------------+------------------+------------------+-------+----------+-----------+
# |  count|                55|    55|                55|                55|                55|     55|        55|         55|
# |   mean|              28.0|  NULL| 7.618181818181818|2.6363636363636362|10.381818181818181|   NULL|      NULL|       NULL|
# | stddev|16.020819787597222|  NULL|3.5719634039170334|1.2526067096353786| 5.955050483633725|   NULL|      NULL|       NULL|
# |    min|                 1|Item 1|                 1|                 1|                 1|Brand 1|Category 1|  Sub Cat 1|
# |    max|                55|Item 9|                13|                 5|                21|Brand 9|Category 5|  Sub Cat 8|
# +-------+------------------+------+------------------+------------------+------------------+-------+----------+-----------+

# %%
# Display basic statistical summary (count, mean, stddev, min, max) for numeric columns in the 'sales' DataFrame

display(sales.describe())
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 9, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, a5b21d96-a522-409b-8731-6d0950e0370b)

# %%
# Display summary statistics (count, mean, stddev, min, max) for the 'geography' DataFrame

display(geography.summary())
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 10, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, a7d74037-33ed-4214-a7e7-7cbc3800a2b6)

# %%
# Display summary statistics (count, mean, stddev, min, max) for the 'sales' DataFrame
display(sales.summary())
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 11, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 4631530d-4ac2-4101-a1c3-de21c65b6338)

# %%
# Filter rows based on column cityId

sales_filter = sales.filter(sales.CustomerId.between(59,62))
customer_filter = customer.filter(customer.CustomerId.between(50,60))
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 12, Finished, Available, Finished)

# %%
# Inner join between sales and customer data

inner_join_df = sales_filter.join(customer_filter, "CustomerId", "inner")
print("Inner join DataFrame:")
display(inner_join_df)
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 13, Finished, Available, Finished)
# Inner join DataFrame:
# SynapseWidget(Synapse.DataFrame, 7094ec75-1dff-4d19-9346-116a085d2d7d)

# %%
# Left join between sales and customer data

left_join_df = sales_filter.join(customer_filter, "CustomerId", "left")
print("left join DataFrame:")
display(left_join_df)
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 14, Finished, Available, Finished)
# left join DataFrame:
# SynapseWidget(Synapse.DataFrame, e1d26551-5ab1-4c39-9cba-96d42fd74eaa)

# %%
# right join between sales and customer data

right_join_df = sales_filter.join(customer_filter, "CustomerId", "right")
print("right join DataFrame:")
display(right_join_df)
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 15, Finished, Available, Finished)
# right join DataFrame:
# SynapseWidget(Synapse.DataFrame, f2108e78-418e-4db0-b32b-79dff0a54d8a)

# %%
# full join between sales and customer data

full_join_df = sales_filter.join(customer_filter, "CustomerId", "full")
print("full join DataFrame:")
display(full_join_df)
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 16, Finished, Available, Finished)
# full join DataFrame:
# SynapseWidget(Synapse.DataFrame, bac7f8e3-8c76-4a2e-8836-c5758db90a71)

# %%
# Leftanti join between sales and customer data

leftanti_join_df = sales_filter.join(customer_filter, "CustomerId", "leftanti")
print("leftAnti join DataFrame:")
display(leftanti_join_df)
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 24, Finished, Available, Finished)
# leftAnti join DataFrame:
# SynapseWidget(Synapse.DataFrame, 12f1e34a-cc22-47cd-b3b9-a80b1707c0ff)

# %%
# cross join between sales and customer data

cross_join_df = sales_filter.crossJoin(customer_filter)
print("Cross join DataFrame:")
display(cross_join_df)
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 21, Finished, Available, Finished)
# Cross join DataFrame:
# SynapseWidget(Synapse.DataFrame, 80e5961e-7cb2-42e9-9c31-08aea2867372)

# %%
customer = customer.drop("state","city")
display(customer)
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 29, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, e744d5bd-da2e-4a29-945b-58658dc71754)

# %%
display(customer)
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 31, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, d24975ef-4495-4d5a-93e1-ea35721aa476)

# %%
sales_customer = sales.join(customer, "CustomerId")
sales_customer_geo = sales_customer.join(geography, "CityId")

# perform the join operation
sales_all = sales_customer_geo.join(item, sales.ItemID == item.ItemId, "inner")

# show all result of the join
print("inner join dataframe:")

display(sales_all)
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 32, Finished, Available, Finished)
# inner join dataframe:
# SynapseWidget(Synapse.DataFrame, ebf1d551-c43c-445c-b1cf-3214117834f8)

# %%
print(sales_all.columns)
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 33, Finished, Available, Finished)
# ['CityId', 'CustomerId', 'OrderNo', 'ItemID', 'SalesDate', 'DeilveryDate', 'Qty', 'Price', 'cost', 'DiscountPercent', 'Age', 'Name', 'City', 'State', 'ItemId', 'Name', 'BrandId', 'CategoryId', 'SubCategoryId', 'Brand', 'Category', 'SubCategory']

# %%
from pyspark.sql.functions import col, expr

# Adding calculated columns
sales_all = sales_all.withColumn("Gross", col("Qty") * col("Price"))
sales_all = sales_all.withColumn("COGS", col("Qty") * col("Cost"))
sales_all = sales_all.withColumn("Discount", col("Qty") * col("Price") * col("DiscountPercent"))

# display the Dataframe with new columns
display(sales_all)
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 37, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 62883654-a150-48e1-a05d-cee9fbd3d0df)

# %%
# Grouping by city and state

grouped_city_state = sales_all.groupBy("City", "State").agg(
    expr("sum(Gross) as TotalGross"),
    expr("sum(COGS) as TotalCOGS"),
    expr("sum(Discount) as TotalDiscount")
)
grouped_city_state.show()
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 38, Finished, Available, Finished)
# +-----------+------------+----------+---------+-------------+
# |       City|       State|TotalGross|TotalCOGS|TotalDiscount|
# +-----------+------------+----------+---------+-------------+
# | Cincinnati|        Ohio|     65548|    45555|      1350225|
# |     Austin|       Texas|    115566|    76911|      2736101|
# | Pittsburgh|Pennsylvania|     89223|    59528|      2302992|
# |   Columbus|        Ohio|     85842|    57465|      2032290|
# |     Tucson|     Arizona|     94897|    62197|      1865520|
# |   San Jose|  California|    107614|    73180|      2604910|
# |Minneapolis|   Minnesota|     84282|    54374|      1994417|
# |   Chandler|     Arizona|     54105|    36630|      1282213|
# |     Laredo|       Texas|     96928|    61701|      2121157|
# |    Garland|       Texas|     77301|    50063|      1728297|
# |    Fremont|  California|     85654|    57007|      2295171|
# |    Detroit|    Michigan|     98973|    67748|      2337910|
# | Long Beach|  California|    145006|    96550|      3501724|
# |  Las Vegas|      Nevada|    112437|    74856|      2779184|
# |    Orlando|     Florida|     98157|    65048|      2626627|
# |      Tulsa|    Oklahoma|    140088|    93958|      3241022|
# |     Irvine|  California|     57105|    38783|      1189847|
# |   Portland|      Oregon|    126208|    82344|      2812711|
# | Saint Paul|   Minnesota|    116202|    76285|      2342545|
# |   New York|    New York|    129860|    86492|      3232233|
# +-----------+------------+----------+---------+-------------+
# only showing top 20 rows

# %%
# Creates a delta lake table named sales delta

sales.write.format("delta").saveAsTable("sales_delta")
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 40, Finished, Available, Finished)

# %%
# Creates a delta lake table named geography

geography.write.format("delta").mode("overwrite").save("Tables/geography")
# Out:
# StatementMeta(, 04ccf37c-cbc8-4f77-af90-a685870f9621, 41, Finished, Available, Finished)
